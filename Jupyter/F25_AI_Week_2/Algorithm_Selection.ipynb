# %% [markdown]
# For each one provide a descrip/on of what it does and how it is used
# Try and build simple examples in a Jupyter Notebook

# %% [markdown]
# # Linear Regression
#
# ### What it does:
# Models the relationship between a dependent variable and a independent variables using a straight line.
#
# ### How it is used:
# Predicts numerical values, such as house prices or stock prices.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv('kc_house_data.csv')

X = data[['sqft_living']].values  # Feature: Ground Living Area
y = data['price'].values    # Target: SalePrice

# Initialize and fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Predict using the model
y_pred = model.predict(X)

# Plotting the results
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X, y_pred, color='red', label='Regression line')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression: House Prices Prediction')
#plt.legend()
plt.show()

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# # Decision Trees
#
# ### What it does:
#
#
# ### How it is used:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('iris.csv')
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('iris.csv')

X = df[['sepal_length', 'sepal_width']].values
y = df['species'].values

label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

dt_model = DecisionTreeClassifier()
dt_model.fit(X, y_encoded)


plt.scatter(X[:, 0], X[:, 1], c=y_encoded, cmap='coolwarm', marker='o')
plt.title('Decision Tree')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # Random Forest
#
# ### What it does:
#
#
# ### How it is used:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier


df = pd.read_csv('covtype.csv', nrows=50)

X = df.iloc[:, 1:3].values
y = df.iloc[:, 0].values 

rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', marker='o')
plt.title('Random Forest')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # Support Vector Machines (SVMs)
#
# ### What it does:
#
#
# ### How it is used:

# %%
from sklearn.svm import SVC


svm_model = SVC()
svm_model.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', marker='o')
plt.title('Support Vector Machine (SVM)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # Naive Bayes
#
# ### What it does:
#
#
# ### How it is used:

# %%
from sklearn.naive_bayes import GaussianNB


nb_model = GaussianNB()
nb_model.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', marker='o')
plt.title('Naive Bayes')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # K-neares Neighbors (KNN)
#
# ### What it does:
#
# ### How it is used:

# %%
from sklearn.neighbors import KNeighborsClassifier


knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', marker='o')
plt.title('K-Nearest Neighbors (KNN)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # Gradient Boosting Machines (GBMs)
#
# ### What it does:
#
# ### How it is used:

# %%
from sklearn.ensemble import GradientBoostingClassifier


gbm_model = GradientBoostingClassifier()
gbm_model.fit(X, y)


plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', marker='o')
plt.title('Gradient Boosting Machines (GBM)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %% [markdown]
# # K-Means clustering
#
# ### What it does:
#
# ### How it is used:

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs


X, y = make_blobs(n_samples=300, centers=3, random_state=42)


kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)


plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=200, c='red', label='Centroids')
plt.title('K-Means Clustering')
plt.legend()
plt.show()

# %% [markdown]
# # Principal Component Analysis (PCA)
#
# ### What it does:
#
# ### How it is used:

# %%
from sklearn.decomposition import PCA
from sklearn.datasets import make_blobs


X, y = make_blobs(n_samples=300, centers=3, random_state=42)


pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)


plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis')
plt.title('Principal Component Analysis (PCA)')
plt.show()

# %% [markdown]
# # DBSCAN
#
# ### What it does:
#
# ### How it is used:

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons


X, y = make_moons(n_samples=300, noise=0.1, random_state=42)


dbscan = DBSCAN(eps=0.2, min_samples=5)
y_dbscan = dbscan.fit_predict(X)


plt.scatter(X[:, 0], X[:, 1], c=y_dbscan, cmap='viridis')
plt.title('DBSCAN Clustering')
plt.show()
